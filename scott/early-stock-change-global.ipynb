# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import os
import numpy as np

#covid_data3 = covid_data2.transpose()
#covid_data3.head()
#covid_data3.to_csv("covid_global.csv")

# data files
#covid_file4 = "covid_global2.csv"

# Read the data 
#covid_data4 = pd.read_csv(covid_file4)

# Display the data table for preview
#covid_data4.head()

# %%
# data files
covid_file5 = "early_covid_stock_price_change_global.csv"

# Read the data 
covid_stock_price5_df = pd.read_csv(covid_file5)

# Display the data table for preview
covid_stock_price5_df.head()
# Out:
#    Unnamed: 0      Date  DOW_Change  SP500_Change  NASDAQ_Change  Total_Deaths
# 0         0.0  2/3/2020      -80.16        -13.26     -82.680664         426.0
# 1         1.0  2/4/2020     -110.89        -16.98     -69.580079          66.0
# 2         2.0  2/5/2020     -242.12         -9.78      65.419921          72.0
# 3         3.0  2/6/2020        8.81         -0.86     -31.169922          70.0
# 4         4.0  2/7/2020      184.41          7.83       6.129882          85.0

# %%
del covid_stock_price5_df['Unnamed: 0']

# %%
covid_stock_price5_df
# Out:
#          Date  DOW_Change  SP500_Change  NASDAQ_Change  Total_Deaths
# 0    2/3/2020      -80.16        -13.26     -82.680664         426.0
# 1    2/4/2020     -110.89        -16.98     -69.580079          66.0
# 2    2/5/2020     -242.12         -9.78      65.419921          72.0
# 3    2/6/2020        8.81         -0.86     -31.169922          70.0
# 4    2/7/2020      184.41          7.83       6.129882          85.0
# ..        ...         ...           ...            ...           ...
# 265       NaN         NaN           NaN            NaN           NaN
# 266       NaN         NaN           NaN            NaN           NaN
# 267       NaN         NaN           NaN            NaN           NaN
# 268       NaN         NaN           NaN            NaN           NaN
# 269       NaN         NaN           NaN            NaN           NaN
#
# [270 rows x 5 columns]

# %%
covid_stock_price5_df.dropna()
# Out:
#          Date  DOW_Change  SP500_Change  NASDAQ_Change  Total_Deaths
# 0    2/3/2020      -80.16        -13.26     -82.680664         426.0
# 1    2/4/2020     -110.89        -16.98     -69.580079          66.0
# 2    2/5/2020     -242.12         -9.78      65.419921          72.0
# 3    2/6/2020        8.81         -0.86     -31.169922          70.0
# 4    2/7/2020      184.41          7.83       6.129882          85.0
# 5   2/10/2020     -281.16        -33.81    -134.759765         107.0
# 6   2/11/2020      114.37          8.12      41.949218         100.0
# 7   2/12/2020     -144.67         -8.95     -37.360352           5.0
# 8   2/13/2020       12.72         -8.04     -54.929688         253.0
# 9   2/14/2020       42.39         -2.08      -2.279297         152.0
# 10  2/18/2020       50.59         -1.25     -53.700195         140.0
# 11  2/19/2020      -35.33         -5.76     -34.370118         115.0
# 12  2/20/2020       76.27          7.22      48.230468         125.0
# 13  2/21/2020      154.12         22.75     131.419922           4.0
# 14  2/24/2020      442.13         31.72     -32.839843         160.0
# 15  2/25/2020      956.29        110.73     335.589843          80.0
# 16  2/26/2020      201.87         23.51      30.769532          61.0
# 17  2/27/2020      759.36         83.78     177.549804          43.0
# 18  2/28/2020     -138.53        -37.32    -297.629883          59.0
# 19   3/2/2020    -1112.81       -115.95    -285.030274          89.0
# 20   3/3/2020      845.06         93.09     281.009765          75.0
# 21   3/4/2020     -707.18        -84.37    -183.990235          95.0
# 22   3/5/2020      550.64         51.76      51.500000          94.0
# 23   3/6/2020     -407.57        -18.17    -106.600586         111.0
# 24   3/9/2020     1141.34        117.33       7.250000         190.0
# 25  3/10/2020     -565.16        -68.75    -124.490234         274.0
# 26  3/11/2020     1051.41         84.22     184.200195         344.0
# 27  3/12/2020      984.09        150.22     196.780273         306.0
# 28  3/13/2020    -1211.80       -141.03    -264.489746         497.0
# 29  3/16/2020      729.01        122.46     488.140136         678.0
# 30  3/17/2020     -750.33       -103.53    -262.779785         814.0
# 31  3/18/2020      289.77         38.40     -87.520020         907.0
# 32  3/19/2020     -257.18        -15.91    -154.129883        1111.0
# 33  3/20/2020     1079.17        127.02     368.549804        1485.0
# 34  3/23/2020      436.43         53.31     -13.390137        1949.0
# 35  3/24/2020     -982.72       -102.89    -221.709961        2290.0
# 36  3/25/2020     -150.21        -17.79      37.060058        2810.0
# 37  3/26/2020    -1083.79       -128.78    -335.330078        3035.0
# 38  3/27/2020      261.69         14.40      51.870117        3488.0
# 39  3/30/2020     -649.26        -67.67    -190.689941        4081.0
# 40  3/31/2020      291.26         30.10      39.959961        4748.0

# %%
covid_stock_price5_df.to_csv("early.csv")

# %%
# data files
covid_file6 = "early2.csv"

# Read the data 
covid_stock_price6_df = pd.read_csv(covid_file6)

# Display the data table for preview
covid_stock_price6_df.head()
# Out:
#        Date  DOW_Change  SP500_Change  NASDAQ_Change  Total_Deaths
# 0  2/3/2020      -80.16        -13.26     -82.680664           426
# 1  2/4/2020     -110.89        -16.98     -69.580079            66
# 2  2/5/2020     -242.12         -9.78      65.419921            72
# 3  2/6/2020        8.81         -0.86     -31.169922            70
# 4  2/7/2020      184.41          7.83       6.129882            85

# %%
covid_stock_price6_df
# Out:
#          Date  DOW_Change  SP500_Change  NASDAQ_Change  Total_Deaths
# 0    2/3/2020      -80.16        -13.26     -82.680664           426
# 1    2/4/2020     -110.89        -16.98     -69.580079            66
# 2    2/5/2020     -242.12         -9.78      65.419921            72
# 3    2/6/2020        8.81         -0.86     -31.169922            70
# 4    2/7/2020      184.41          7.83       6.129882            85
# 5   2/10/2020     -281.16        -33.81    -134.759765           107
# 6   2/11/2020      114.37          8.12      41.949218           100
# 7   2/12/2020     -144.67         -8.95     -37.360352             5
# 8   2/13/2020       12.72         -8.04     -54.929688           253
# 9   2/14/2020       42.39         -2.08      -2.279297           152
# 10  2/18/2020       50.59         -1.25     -53.700195           140
# 11  2/19/2020      -35.33         -5.76     -34.370118           115
# 12  2/20/2020       76.27          7.22      48.230468           125
# 13  2/21/2020      154.12         22.75     131.419922             4
# 14  2/24/2020      442.13         31.72     -32.839843           160
# 15  2/25/2020      956.29        110.73     335.589843            80
# 16  2/26/2020      201.87         23.51      30.769532            61
# 17  2/27/2020      759.36         83.78     177.549804            43
# 18  2/28/2020     -138.53        -37.32    -297.629883            59
# 19   3/2/2020    -1112.81       -115.95    -285.030274            89
# 20   3/3/2020      845.06         93.09     281.009765            75
# 21   3/4/2020     -707.18        -84.37    -183.990235            95
# 22   3/5/2020      550.64         51.76      51.500000            94
# 23   3/6/2020     -407.57        -18.17    -106.600586           111
# 24   3/9/2020     1141.34        117.33       7.250000           190
# 25  3/10/2020     -565.16        -68.75    -124.490234           274
# 26  3/11/2020     1051.41         84.22     184.200195           344
# 27  3/12/2020      984.09        150.22     196.780273           306
# 28  3/13/2020    -1211.80       -141.03    -264.489746           497
# 29  3/16/2020      729.01        122.46     488.140136           678
# 30  3/17/2020     -750.33       -103.53    -262.779785           814
# 31  3/18/2020      289.77         38.40     -87.520020           907
# 32  3/19/2020     -257.18        -15.91    -154.129883          1111
# 33  3/20/2020     1079.17        127.02     368.549804          1485
# 34  3/23/2020      436.43         53.31     -13.390137          1949
# 35  3/24/2020     -982.72       -102.89    -221.709961          2290
# 36  3/25/2020     -150.21        -17.79      37.060058          2810
# 37  3/26/2020    -1083.79       -128.78    -335.330078          3035
# 38  3/27/2020      261.69         14.40      51.870117          3488
# 39  3/30/2020     -649.26        -67.67    -190.689941          4081
# 40  3/31/2020      291.26         30.10      39.959961          4748

# %%
from matplotlib.pyplot import figure

x = covid_stock_price6_df['Date']
a = covid_stock_price6_df['DOW_Change']
b = covid_stock_price6_df['NASDAQ_Change']
c = covid_stock_price6_df['SP500_Change']
d = covid_stock_price6_df['Total_Deaths']

figure(figsize=(16, 10))
plt.plot(x, b, color="blue", label="NASDAQ Change")
plt.plot(x, d, color="red", label="Covid Deaths")

plt.xticks(np.arange(0, len(x)+1, 10),rotation ='vertical')
plt.title("NASDAQ vs. Covid Deaths - Global")
plt.xlabel("Date")
plt.ylabel("Stock Price Change / Deaths")
plt.legend(loc="best")
#plt.savefig("covid-nasdaq5.png")
plt.show()

# %%
# Plot the charts and apply some styling
figure(figsize=(16, 10))
plt.plot(x, c, color="black", label="S&P 500 Change")
plt.plot(x, d, color="red", label="Covid Deaths")

plt.xticks(np.arange(0, len(x)+1, 10),rotation ='vertical')
plt.title("S&P 500 vs. Covid Deaths - Global")
plt.xlabel("Date")
plt.ylabel("Stock Price Change / Deaths")
plt.xticks(rotation ='vertical')
plt.legend(loc="best")
#plt.savefig("covid-sp5004.png")
plt.show()

# %%
# Plot the charts and apply some styling
figure(figsize=(16, 10))
plt.plot(x, a, color='green', label="DOW Change")
plt.plot(x, d, color="red", label="Covid Deaths")

plt.xticks(np.arange(0, len(x)+1, 10),rotation ='vertical')
plt.title("DOW vs. Covid Deaths - Global")
plt.xlabel("Date")
plt.ylabel("Stock Price Change / Deaths")
plt.xticks(rotation ='vertical')
plt.legend(loc="best")
#plt.savefig("covid-dow4.png")
plt.show()

# %%
figure(figsize=(16, 10))
plt.plot(x, a, color='green', label="DOW")
plt.plot(x, b, color="blue", label="NASDAQ")
plt.plot(x, c, color="black", label="S&P 500")
plt.plot(x, d, color="red", label="Global Covid Deaths")

plt.xticks(np.arange(0, len(x)+1, 10),rotation ='vertical')
#plt.yticks(np.arange(0, max(y), 2))
plt.title("Stock Market Over Time")
plt.xlabel("Date")
plt.ylabel("Stock Price / Deaths")
plt.legend(loc="best")
#plt.savefig("covid-stocks4.png")
plt.show()

# %%
correlation13 = st.pearsonr(b,d)
print(f"The correlation between Daily NASDAQ Change and Global Covid Deaths is {round(correlation13[0],2)}")
print(f"""The r-squared value is {round((correlation13[0]**2),2)}""")
# Out:
# The correlation between Daily NASDAQ Change and Global Covid Deaths is -0.13
# The r-squared value is 0.02

# %%
correlation14 = st.pearsonr(c,d)
print(f"The correlation between Daily S&P 500 Change and Global Covid Deaths is {round(correlation14[0],2)}")
print(f"""The r-squared value is {round((correlation14[0]**2),2)}""")
# Out:
# The correlation between Daily S&P 500 Change and Global Covid Deaths is -0.17
# The r-squared value is 0.03

# %%
correlation15 = st.pearsonr(a,d)
print(f"The correlation between Daily DOW Change and Global Covid Deaths is {round(correlation15[0],2)}")
print(f"""The r-squared value is {round((correlation15[0]**2),2)}""")
# Out:
# The correlation between Daily DOW Change and Global Covid Deaths is -0.17
# The r-squared value is 0.03

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(b, d)
regress_values = b * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot the linear regression model on top of the previous scatter plot.
plt.scatter(b,d, color="lightcoral", edgecolors="black")
plt.plot(b,regress_values,"r-")
#plt.annotate(line_eq,(7000,4000),fontsize=15,color="red")
plt.xlabel("NASDAQ Change")
plt.ylabel("Covid Deaths")
plt.title("Global Covid Deaths vs. NASDAQ")
#plt.savefig("")
plt.show()
print(f"The correlation between Daily NASDAQ Change and Global Covid Deaths is {round(correlation13[0],2)}")
print(f"""The r-squared value is {round((correlation13[0]**2),2)}""")
# Out:
# The correlation between Daily NASDAQ Change and Global Covid Deaths is -0.13
# The r-squared value is 0.02

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(c, d)
regress_values = c * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot the linear regression model on top of the previous scatter plot.
plt.scatter(c,d, color="lightcoral", edgecolors="black")
plt.plot(c,regress_values,"r-")
#plt.annotate(line_eq,(2300,4000),fontsize=15,color="red")
plt.xlabel("S&P 500 Change")
plt.ylabel("Covid Deaths")
plt.title("Global Covid Deaths vs. S&P 500")
#plt.savefig("")
plt.show()
print(f"The correlation between Daily S&P 500 Change and Global Covid Deaths is {round(correlation14[0],2)}")
print(f"""The r-squared value is {round((correlation14[0]**2),2)}""")
# Out:
# The correlation between Daily S&P 500 Change and Global Covid Deaths is -0.17
# The r-squared value is 0.03

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(a, d)
regress_values = a * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot the linear regression model on top of the previous scatter plot.
plt.scatter(a,d, color="lightcoral", edgecolors="black")
plt.plot(a,regress_values,"r-")
#plt.annotate(line_eq,(19000,4000),fontsize=15,color="red")
plt.xlabel("DOW Change")
plt.ylabel("Covid Deaths")
plt.title("Global Covid Deaths vs. DOW")
#plt.savefig("")
plt.show()
print(f"The correlation between Daily DOW Change and Global Covid Deaths is {round(correlation15[0],2)}")
print(f"""The r-squared value is {round((correlation15[0]**2),2)}""")
# Out:
# The correlation between Daily DOW Change and Global Covid Deaths is -0.17
# The r-squared value is 0.03
